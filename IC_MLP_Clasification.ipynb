# %% [markdown]
# <a href="https://colab.research.google.com/github/maxi9113/colab_notebook/blob/main/IC_MLP_Clasification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

file_path = '/content/drive/MyDrive/Colab Notebooks/Files/files_mlp_clasifications.csv'
df = pd.read_csv(file_path, sep=';')

# Display the first few rows of the DataFrame
display(df.head())
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Normalizar datos
scaler = StandardScaler()
df_norm = scaler.fit_transform(df_shuffled)

#separacion de datos
df_train, df_test = train_test_split(df_norm, test_size=0.3, random_state=42)
# Out:
#        x1      x2      x3      x4  d1  d2  d3
# 0  0.3841  0.2021  0.0000  0.2438   1   0   0
# 1  0.1765  0.1613  0.3401  0.0843   1   0   0
# 2  0.3170  0.5786  0.3387  0.4192   0   1   0
# 3  0.2467  0.0337  0.2699  0.3454   1   0   0
# 4  0.6102  0.8192  0.4679  0.4762   0   1   0
